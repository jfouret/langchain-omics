# %% [raw]
# ---
# sidebar_label: Omics
# ---

# %% [markdown]
# # SRARetriever
#
# The `SRARetriever` retrieves genomic samples, studies, experiments, and runs from the Sequence Read Archive (SRA) using the EBI Search API. It supports searching across different SRA entity types and can retrieve cross-references and related entities.

# %% [markdown]
# ### Installation
#
# This retriever lives in the `langchain-omics` package:

# %%
# %pip install -qU langchain-omics

# %% [markdown]
# ## Instantiation
#
# Now we can instantiate our retriever:
#
# - TODO: Update model instantiation with relevant params.

# %%
from langchain_omics import SRARetriever

# Initialize the retriever with default parameters (searches SRA samples)
retriever = SRARetriever()

# %% [markdown]
# ## Usage

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

# %%
for doc in docs:
  print(doc.page_content)
# Out:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }
# {
#   "id": "SAMN38194869",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194869",
#     "id": "SAMN38194869",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
# ...

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
query = 'clinical AND ("respiratory syncitial virus" OR RSV)'

docs = retriever.invoke(query)

print(f"Found {len(docs)} documents")
if docs:
    print("\nFirst document:")
    print(docs[0].page_content)
# Out:
# Found 10 documents
#
# First document:
# {
#   "id": "SAMN38194863",
#   "type": "Sample",
#   "database": "sra-sample",
#   "fields": {
#     "acc": "SAMN38194863",
#     "id": "SAMN38194863",
#     "description": "Pathogen: clinical or host-associated sample from Human respiratory syncytial virus A",
#     "scientific_name": "Human respiratory syncytial virus A",
#     "country": "Australia",
#     "region": "Sydney",
#     "collection_date": "20220511",
#     "center_name": "University of New South Wales",
#     "host": "Homo sapiens",
#     "BIOSAMPLE": "SAMN38194863",
#     "TAXON": "208893"
#   },
#   "cross_references": {
#     "BIOSAMPLE": [
#       "SAMN38194863"
#     ],
#     "TAXON": [
#       "208893"
#     ]
#   }
# }

# %%
docs_100[1]

# %% [markdown]
# ## Use within a chain
#
# Like other retrievers, OmicsRetriever can be incorporated into LLM applications via [chains](/docs/how_to/sequence/).
#
# We will need a LLM or chat model:
#
# import ChatModelTabs from "@theme/ChatModelTabs";
#
# <ChatModelTabs customVarName="llm" />

# %%
# | output: false
# | echo: false

from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo-0125", temperature=0)

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

prompt = ChatPromptTemplate.from_template(
    """Answer the question based only on the context provided.

Context: {context}

Question: {question}"""
)


def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
chain.invoke("...")

# %% [markdown]
# ## TODO: Any functionality or considerations specific to this retriever
#
# Fill in or delete if not relevant.

# %% [markdown]
# ## API reference
#
# For detailed documentation of all OmicsRetriever features and configurations head to the [API reference](https://api.python.langchain.com/en/latest/retrievers/langchain_omics.retrievers.Omics.OmicsRetriever.html).
